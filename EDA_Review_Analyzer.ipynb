# %%
import os
import pickle
import numpy as np
import pandas as pd

import seaborn as sns

# %%
df = pd.DataFrame();
with (open('model_data.pickle','rb')) as openfile:
    df = pickle.load(openfile)
df.head()
# Out:
#               business_id  business_stars  review_count  \
# 0  6iYb2HFDywm3zjuRg0shjw             4.0            86
# 1  6iYb2HFDywm3zjuRg0shjw             4.0            86
# 2  6iYb2HFDywm3zjuRg0shjw             4.0            86
# 3  6iYb2HFDywm3zjuRg0shjw             4.0            86
# 4  6iYb2HFDywm3zjuRg0shjw             4.0            86
#
#                                           categories                 user_id  \
# 0  Gastropubs, Food, Beer Gardens, Restaurants, B...  93z0yh-sUpGZS-cSKu6xxA
# 1  Gastropubs, Food, Beer Gardens, Restaurants, B...  Q_CZIvnsDHjpls-EPzzG7Q
# 2  Gastropubs, Food, Beer Gardens, Restaurants, B...  rqxTSFFj5fZNmabY1fmTlw
# 3  Gastropubs, Food, Beer Gardens, Restaurants, B...  vNPxlt5f50q0e2nVAScW3Q
# 4  Gastropubs, Food, Beer Gardens, Restaurants, B...  eXRC79iX60xwA1UuGRuWNg
#
#                                                 text  review_stars  \
# 0  Stopped in on a busy Friday night. Despite the...             5
# ...

# %%
df.columns
# Out:
# Index(['business_id', 'business_stars', 'review_count', 'categories',
#        'user_id', 'text', 'review_stars', 'restaurants_table_service', 'wifi',
#        'bike_parking', 'business_parking', 'business_accepts_credit_cards',
#        'restaurants_reservations', 'wheelchair_accessible', 'caters',
#        'outdoor_seating', 'restaurants_good_for_groups', 'happy_hour',
#        'business_accepts_bitcoin', 'restaurants_price_range2', 'ambience',
#        'has_tv', 'alcohol', 'good_for_meal', 'dogs_allowed',
#        'restaurants_take_out', 'noise_level', 'restaurants_attire',
#        'restaurants_delivery', 'good_for_kids', 'good_for_dancing', 'music'],
#       dtype='object')

# %%
sns.countplot(df.review_stars)
# Out:
# C:\Users\RSanchez\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='review_stars', ylabel='count'>

# %%
df
